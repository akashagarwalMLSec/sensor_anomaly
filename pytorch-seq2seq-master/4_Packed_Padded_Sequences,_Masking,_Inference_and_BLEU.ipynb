# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt-get install jq
# !pip install torchtext==0.6.0
# %cd /content/drive/My\ Drive/Colab\ stuff/sensor_anomaly
# %ls
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# jq is already the newest version (1.5+dfsg-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Requirement already satisfied: torchtext==0.6.0 in /usr/local/lib/python3.6/dist-packages (0.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6.0) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6.0) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6.0) (1.12.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6.0) (0.1.91)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6.0) (1.5.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchtext==0.6.0) (1.18.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.6.0) (1.24.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch->torchtext==0.6.0) (0.16.0)
# /content/drive/My Drive/Colab stuff/sensor_anomaly
# data_aggregation.ipynb    pytorch-seq2seq-master/  train.csv          val.csv
# dataset/                  Sensor2Activity.ipynb    tut4-model2-20.pt  venv/
# deepmind/                 Sensor-Activity-5.txt    tut4-model2.pt
# NMT_in_PyTorch.ipynb      STGCN-PyTorch-master/    tut4-model.pt
# preprocessing_data.ipynb  test.csv                 UAI-master/

# %% [markdown]
# # 4 - Packed Padded Sequences, Masking, Inference and BLEU
#
# ## Introduction
#
# In this notebook we will be adding a few improvements - packed padded sequences and masking - to the model from the previous notebook. Packed padded sequences are used to tell our RNN to skip over padding tokens in our encoder. Masking explicitly forces the model to ignore certain values, such as attention over padded elements. Both of these techniques are commonly used in NLP.
#
# We will also look at how to use our model for inference, by giving it a sentence, seeing what it translates it as and seeing where exactly it pays attention to when translating each word.
#
# Finally, we'll use the BLEU metric to measure the quality of our translations.
#
# ## Preparing Data
#
# First, we'll import all the modules as before, with the addition of the `matplotlib` modules used for viewing the attention.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchtext.data
from torchtext.data import Field, BucketIterator, TabularDataset

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

import random
import math
import time
import pandas as pd
from sklearn.model_selection import train_test_split
from torchtext.data.metrics import bleu_score

# %% [markdown]
# Next, we'll set the random seed for reproducability.

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# When using packed padded sequences, we need to tell PyTorch how long the actual (non-padded) sequences are. Luckily for us, TorchText's `Field` objects allow us to use the `include_lengths` argument, this will cause our `batch.src` to be a tuple. The first element of the tuple is the same as before, a batch of numericalized source sentence as a tensor, and the second element is the non-padded lengths of each source sentence within the batch.

# %%
tokenize_simple = lambda x: x.split()
SRC = Field(tokenize = tokenize_simple, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            include_lengths = True)

TRG = Field(tokenize = tokenize_simple, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True)

# %%
lenofsen = 5
f = open('Sensor-Activity-' + str(lenofsen) +'.txt', encoding='UTF-8').read().strip().split('\n')
lines = f
original_word_pairs = [[w for w in l.split('\t')] for l in lines]
raw_data = {'Sensor' : [line[0] for line in original_word_pairs], 'Activity': [line[1] for line in original_word_pairs]}
df = pd.DataFrame(raw_data, columns=["Sensor", "Activity"])
print(len(df))
train_data, test_data = train_test_split(df, test_size=0.03)
train_data, valid_data = train_test_split(train_data, test_size=0.033)
print(len(train_data), len(test_data), len(valid_data))
train_data.to_csv("train.csv", index=False, header=False)
valid_data.to_csv("val.csv", index=False, header=False)
test_data.to_csv("test.csv", index=False, header=False)
data_fields = [('Sensor', SRC), ('Activity', TRG)]
train_data,valid_data = torchtext.data.TabularDataset.splits(path='./', train='train.csv', validation='val.csv', format='csv', fields=data_fields)
train_data,test_data = torchtext.data.TabularDataset.splits(path='./', train='train.csv', validation='test.csv', format='csv', fields=data_fields)
print(f"Number of training examples: {len(train_data.examples)}")
print(f"Number of validation examples: {len(valid_data.examples)}")
print(f"Number of testing examples: {len(test_data.examples)}")
print(vars(valid_data.examples[700]))
SRC.build_vocab(train_data, valid_data, test_data, min_freq = 1)
TRG.build_vocab(train_data, valid_data, test_data, min_freq = 1)
print(f"Unique tokens in source (sensor) vocabulary: {len(SRC.vocab)}")
print(f"Unique tokens in target (activity) vocabulary: {len(TRG.vocab)}")
# Out:
# 23769
# 22294 714 761
# Number of training examples: 22294
# Number of validation examples: 761
# Number of testing examples: 714
# {'Sensor': ['1', '1', '1', '1', '1'], 'Activity': ['134', '134', '134', '134', '134']}
# Unique tokens in source (sensor) vocabulary: 4862
# Unique tokens in target (activity) vocabulary: 170

# %% [markdown]
# ## Building the Model
#
# ### Encoder
#
# Next up, we define the encoder.
#
# The changes here all within the `forward` method. It now accepts the lengths of the source sentences as well as the sentences themselves.
#
# After the source sentence (padded automatically within the iterator) has been embedded, we can then use `pack_padded_sequence` on it with the lengths of the sentences. `packed_embedded` will then be our packed padded sequence. This can be then fed to our RNN as normal which will return `packed_outputs`, a packed tensor containing all of the hidden states from the sequence, and `hidden` which is simply the final hidden state from our sequence. `hidden` is a standard tensor and not packed in any way, the only difference is that as the input was a packed sequence, this tensor is from the final **non-padded element** in the sequence.
#
# We then unpack our `packed_outputs` using `pad_packed_sequence` which returns the `outputs` and the lengths of each, which we don't need.
#
# The first dimension of `outputs` is the padded sequence lengths however due to using a packed padded sequence the values of tensors when a padding token was the input will be all zeros.

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout):
        super().__init__()
        
        self.embedding = nn.Embedding(input_dim, emb_dim)
        
        self.rnn = nn.GRU(emb_dim, enc_hid_dim, bidirectional = True)
        
        self.fc = nn.Linear(enc_hid_dim * 2, dec_hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_len):
        
        #src = [src len, batch size]
        #src_len = [batch size]
        
        embedded = self.dropout(self.embedding(src))
        
        #embedded = [src len, batch size, emb dim]
                
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, src_len)
                
        packed_outputs, hidden = self.rnn(packed_embedded)
                                 
        #packed_outputs is a packed sequence containing all hidden states
        #hidden is now from the final non-padded element in the batch
            
        outputs, _ = nn.utils.rnn.pad_packed_sequence(packed_outputs) 
            
        #outputs is now a non-packed sequence, all hidden states obtained
        #  when the input is a pad token are all zeros
            
        #outputs = [src len, batch size, hid dim * num directions]
        #hidden = [n layers * num directions, batch size, hid dim]
        
        #hidden is stacked [forward_1, backward_1, forward_2, backward_2, ...]
        #outputs are always from the last layer
        
        #hidden [-2, :, : ] is the last of the forwards RNN 
        #hidden [-1, :, : ] is the last of the backwards RNN
        
        #initial decoder hidden is final hidden state of the forwards and backwards 
        #  encoder RNNs fed through a linear layer
        hidden = torch.tanh(self.fc(torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim = 1)))
        
        #outputs = [src len, batch size, enc hid dim * 2]
        #hidden = [batch size, dec hid dim]
        
        return outputs, hidden

# %% [markdown]
# ### Attention
#
# The attention module is where we calculate the attention values over the source sentence.
#
# Previously, we allowed this module to "pay attention" to padding tokens within the source sentence. However, using *masking*, we can force the attention to only be over non-padding elements.
#
# The `forward` method now takes a `mask` input. This is a **[batch size, source sentence length]** tensor that is 1 when the source sentence token is not a padding token, and 0 when it is a padding token. For example, if the source sentence is: ["hello", "how", "are", "you", "?", `<pad>`, `<pad>`], then the mask would be [1, 1, 1, 1, 1, 0, 0].
#
# We apply the mask after the attention has been calculated, but before it has been normalized by the `softmax` function. It is applied using `masked_fill`. This fills the tensor at each element where the first argument (`mask == 0`) is true, with the value given by the second argument (`-1e10`). In other words, it will take the un-normalized attention values, and change the attention values over padded elements to be `-1e10`. As these numbers will be miniscule compared to the other values they will become zero when passed through the `softmax` layer, ensuring no attention is payed to padding tokens in the source sentence.

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim, dec_hid_dim):
        super().__init__()
        
        self.attn = nn.Linear((enc_hid_dim * 2) + dec_hid_dim, dec_hid_dim)
        self.v = nn.Linear(dec_hid_dim, 1, bias = False)
        
    def forward(self, hidden, encoder_outputs, mask):
        
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim * 2]
        
        batch_size = encoder_outputs.shape[1]
        src_len = encoder_outputs.shape[0]
        
        #repeat decoder hidden state src_len times
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)
  
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #hidden = [batch size, src len, dec hid dim]
        #encoder_outputs = [batch size, src len, enc hid dim * 2]
        
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2))) 
        
        #energy = [batch size, src len, dec hid dim]

        attention = self.v(energy).squeeze(2)
        
        #attention = [batch size, src len]
        
        attention = attention.masked_fill(mask == 0, -1e10)
        
        return F.softmax(attention, dim = 1)

# %% [markdown]
# ### Decoder
#
# The decoder only needs a few small changes. It needs to accept a mask over the source sentence and pass this to the attention module. As we want to view the values of attention during inference, we also return the attention tensor.

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, enc_hid_dim, dec_hid_dim, dropout, attention):
        super().__init__()

        self.output_dim = output_dim
        self.attention = attention
        
        self.embedding = nn.Embedding(output_dim, emb_dim)
        
        self.rnn = nn.GRU((enc_hid_dim * 2) + emb_dim, dec_hid_dim)
        
        self.fc_out = nn.Linear((enc_hid_dim * 2) + dec_hid_dim + emb_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, input, hidden, encoder_outputs, mask):
             
        #input = [batch size]
        #hidden = [batch size, dec hid dim]
        #encoder_outputs = [src len, batch size, enc hid dim * 2]
        #mask = [batch size, src len]
        
        input = input.unsqueeze(0)
        
        #input = [1, batch size]
        
        embedded = self.dropout(self.embedding(input))
        
        #embedded = [1, batch size, emb dim]
        
        a = self.attention(hidden, encoder_outputs, mask)
                
        #a = [batch size, src len]
        
        a = a.unsqueeze(1)
        
        #a = [batch size, 1, src len]
        
        encoder_outputs = encoder_outputs.permute(1, 0, 2)
        
        #encoder_outputs = [batch size, src len, enc hid dim * 2]
        
        weighted = torch.bmm(a, encoder_outputs)
        
        #weighted = [batch size, 1, enc hid dim * 2]
        
        weighted = weighted.permute(1, 0, 2)
        
        #weighted = [1, batch size, enc hid dim * 2]
        
        rnn_input = torch.cat((embedded, weighted), dim = 2)
        
        #rnn_input = [1, batch size, (enc hid dim * 2) + emb dim]
            
        output, hidden = self.rnn(rnn_input, hidden.unsqueeze(0))
        
        #output = [seq len, batch size, dec hid dim * n directions]
        #hidden = [n layers * n directions, batch size, dec hid dim]
        
        #seq len, n layers and n directions will always be 1 in this decoder, therefore:
        #output = [1, batch size, dec hid dim]
        #hidden = [1, batch size, dec hid dim]
        #this also means that output == hidden
        assert (output == hidden).all()
        
        embedded = embedded.squeeze(0)
        output = output.squeeze(0)
        weighted = weighted.squeeze(0)
        
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim = 1))
        
        #prediction = [batch size, output dim]
        
        return prediction, hidden.squeeze(0), a.squeeze(1)

# %% [markdown]
# ### Seq2Seq
#
# The overarching seq2seq model also needs a few changes for packed padded sequences, masking and inference.
#
# We need to tell it what the indexes are for the pad token and also pass the source sentence lengths as input to the `forward` method.
#
# We use the pad token index to create the masks, by creating a mask tensor that is 1 wherever the source sentence is not equal to the pad token. This is all done within the `create_mask` function.
#
# The sequence lengths as needed to pass to the encoder to use packed padded sequences.
#
# The attention at each time-step is stored in the `attentions`

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, src_pad_idx, device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.device = device
        
    def create_mask(self, src):
        mask = (src != self.src_pad_idx).permute(1, 0)
        return mask
        
    def forward(self, src, src_len, trg, teacher_forcing_ratio = 0.5):
        
        #src = [src len, batch size]
        #src_len = [batch size]
        #trg = [trg len, batch size]
        #teacher_forcing_ratio is probability to use teacher forcing
        #e.g. if teacher_forcing_ratio is 0.75 we use teacher forcing 75% of the time
                    
        batch_size = src.shape[1]
        trg_len = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        
        #tensor to store decoder outputs
        outputs = torch.zeros(trg_len, batch_size, trg_vocab_size).to(self.device)
        
        #encoder_outputs is all hidden states of the input sequence, back and forwards
        #hidden is the final forward and backward hidden states, passed through a linear layer
        encoder_outputs, hidden = self.encoder(src, src_len)
                
        #first input to the decoder is the <sos> tokens
        input = trg[0,:]
        
        mask = self.create_mask(src)

        #mask = [batch size, src len]
                
        for t in range(1, trg_len):
            
            #insert input token embedding, previous hidden state, all encoder hidden states 
            #  and mask
            #receive output tensor (predictions) and new hidden state
            output, hidden, _ = self.decoder(input, hidden, encoder_outputs, mask)
            
            #place predictions in a tensor holding predictions for each token
            outputs[t] = output
            
            #decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            
            #get the highest predicted token from our predictions
            top1 = output.argmax(1) 
            
            #if teacher forcing, use actual next token as next input
            #if not, use predicted token
            input = trg[t] if teacher_force else top1
            
        return outputs

# %% [markdown]
# Then, we initialize the model parameters.

# %%
def init_weights(m):
    for name, param in m.named_parameters():
        if 'weight' in name:
            nn.init.normal_(param.data, mean=0, std=0.01)
        else:
            nn.init.constant_(param.data, 0)

# %% [markdown]
# Next, we'll define our training and evaluation loops.
#
# As we are using `include_lengths = True` for our source field, `batch.src` is now a tuple with the first element being the numericalized tensor representing the sentence and the second element being the lengths of each sentence within the batch.
#
# Our model also returns the attention vectors over the batch of source source sentences for each decoding time-step. We won't use these during the training/evaluation, but we will later for inference.

# %%
def train(model, iterator, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    
    for i, batch in enumerate(iterator):
        
        src, src_len = batch.Sensor
        trg = batch.Activity
        
        optimizer.zero_grad()
        
        output = model(src, src_len, trg)
        
        #trg = [trg len, batch size]
        #output = [trg len, batch size, output dim]
        
        output_dim = output.shape[-1]
        
        output = output[1:].view(-1, output_dim)
        trg = trg[1:].view(-1)
        
        #trg = [(trg len - 1) * batch size]
        #output = [(trg len - 1) * batch size, output dim]
        
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        sched.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src, src_len = batch.Sensor
            trg = batch.Activity

            output = model(src, src_len, trg, 0) #turn off teacher forcing
            
            #trg = [trg len, batch size]
            #output = [trg len, batch size, output dim]

            output_dim = output.shape[-1]
            
            output = output[1:].view(-1, output_dim)
            trg = trg[1:].view(-1)

            #trg = [(trg len - 1) * batch size]
            #output = [(trg len - 1) * batch size, output dim]

            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %% [markdown]
# Then, we'll define a useful function for timing how long epochs take.

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %% [markdown]
# ## Inference
#
# Now we can use our trained model to generate translations.
#
# **Note:** these translations will be poor compared to examples shown in paper as they use hidden dimension sizes of 1000 and train for 4 days! They have been cherry picked in order to show off what attention should look like on a sufficiently sized model.
#
# Our `translate_sentence` will do the following:
# - ensure our model is in evaluation mode, which it should always be for inference
# - tokenize the source sentence if it has not been tokenized (is a string)
# - numericalize the source sentence
# - convert it to a tensor and add a batch dimension
# - get the length of the source sentence and convert to a tensor
# - feed the source sentence into the encoder
# - create the mask for the source sentence
# - create a list to hold the output sentence, initialized with an `<sos>` token
# - create a tensor to hold the attention values
# - while we have not hit a maximum length
#   - get the input tensor, which should be either `<sos>` or the last predicted token
#   - feed the input, all encoder outputs, hidden state and mask into the decoder
#   - store attention values
#   - get the predicted next token
#   - add prediction to current output sentence prediction
#   - break if the prediction was an `<eos>` token
# - convert the output sentence from indexes to tokens
# - return the output sentence (with the `<sos>` token removed) and the attention values over the sequence

# %%
def translate_sentence(sentence, src_field, trg_field, model, device, max_len = 50):

    model.eval()
        
    # if isinstance(sentence, str):
    #     nlp = spacy.load('de')
    #     tokens = [token.text.lower() for token in nlp(sentence)]
    # else:
    tokens = [token.lower() for token in sentence]
    tokens = [src_field.init_token] + tokens + [src_field.eos_token]
    src_indexes = [src_field.vocab.stoi[token] for token in tokens]
    
    src_tensor = torch.LongTensor(src_indexes).unsqueeze(1).to(device)

    src_len = torch.LongTensor([len(src_indexes)]).to(device)
    
    with torch.no_grad():
        encoder_outputs, hidden = model.encoder(src_tensor, src_len)

    mask = model.create_mask(src_tensor)
        
    trg_indexes = [trg_field.vocab.stoi[trg_field.init_token]]

    attentions = torch.zeros(max_len, 1, len(src_indexes)).to(device)
    
    for i in range(max_len):

        trg_tensor = torch.LongTensor([trg_indexes[-1]]).to(device)
                
        with torch.no_grad():
            output, hidden, attention = model.decoder(trg_tensor, hidden, encoder_outputs, mask)

        attentions[i] = attention
            
        pred_token = output.argmax(1).item()
        
        trg_indexes.append(pred_token)

        if pred_token == trg_field.vocab.stoi[trg_field.eos_token]:
            break
    
    trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]
    
    return trg_tokens[1:], attentions[:len(trg_tokens)-1]

# %% [markdown]
# Next, we'll make a function that displays the model's attention over the source sentence for each target token generated.

# %%
def display_attention(sentence, translation, attention):
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    
    attention = attention.squeeze(1).cpu().detach().numpy()
    
    cax = ax.matshow(attention, cmap='bone')
   
    ax.tick_params(labelsize=15)
    ax.set_xticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'], 
                       rotation=45)
    ax.set_yticklabels(['']+translation)

    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close()

# %% [markdown]
# Next, we handle the iterators.
#
# One quirk about packed padded sequences is that all elements in the batch need to be sorted by their non-padded lengths in descending order, i.e. the first sentence in the batch needs to be the longest. We use two arguments of the iterator to handle this, `sort_within_batch` which tells the iterator that the contents of the batch need to be sorted, and `sort_key` a function which tells the iterator how to sort the elements in the batch. Here, we sort by the length of the `src` sentence.

# %%
BATCH_SIZE = 128

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.cuda.empty_cache()
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
     batch_size = BATCH_SIZE,
     sort_within_batch = True,
     sort_key = lambda x : len(x.Sensor),
     device = device)

# %% [markdown]
# ## Training the Seq2Seq Model
#
# Next up, initializing the model and placing it on the GPU.

# %% [markdown]
# Then we define our optimizer and criterion.
#
# The `ignore_index` for the criterion needs to be the index of the pad token for the target language, not the source language.

# %%
# Model parameters
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
ENC_EMB_DIM = 400
DEC_EMB_DIM = 80
ENC_HID_DIM = 256
DEC_HID_DIM = 256
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1
SRC_PAD_IDX = SRC.vocab.stoi[SRC.pad_token]

# Model Definition
attn = Attention(ENC_HID_DIM, DEC_HID_DIM)
enc = Encoder(INPUT_DIM, ENC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, ENC_DROPOUT)
dec = Decoder(OUTPUT_DIM, DEC_EMB_DIM, ENC_HID_DIM, DEC_HID_DIM, DEC_DROPOUT, attn)
model = Seq2Seq(enc, dec, SRC_PAD_IDX, device).to(device)
model.apply(init_weights)

# Training parameters
max_lr = 0.001
weight_decay = 1e-4
N_EPOCHS = 200
CLIP = 1
optimizer = optim.Adam(model.parameters(), lr = 1e-4, betas=(0.9, 0.999), weight_decay=weight_decay)
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)
steps_per_epoch=len(train_iterator)
sched = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr, epochs=N_EPOCHS, 
                                                steps_per_epoch=steps_per_epoch)

# %% [markdown]
# We'll print out the number of trainable parameters in the model, noticing that it has the exact same amount of parameters as the model without these improvements.

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 4,094,666 trainable parameters

# %% [markdown]
# The penultimate step is to train our model. Notice how it takes almost half the time as our model without the improvements added in this notebook.

# %%
best_valid_loss = float('inf')

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP)
    valid_loss = evaluate(model, valid_iterator, criterion)
    
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut4-model.pt')
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
    print("Learning rate: ", sched.get_lr())
# Out:
# Epoch: 01 | Time: 0m 6s
# 	Train Loss: 4.127 | Train PPL:  62.002
# 	 Val. Loss: 2.004 |  Val. PPL:   7.420
# Learning rate:  [4.065794860674918e-05]
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:1206: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Epoch: 02 | Time: 0m 6s
# 	Train Loss: 1.863 | Train PPL:   6.445
# 	 Val. Loss: 1.788 |  Val. PPL:   5.975
# Learning rate:  [4.2629990692125207e-05]
# Epoch: 03 | Time: 0m 6s
# 	Train Loss: 1.691 | Train PPL:   5.425
# 	 Val. Loss: 1.658 |  Val. PPL:   5.248
# Learning rate:  [4.591071999636778e-05]
# Epoch: 04 | Time: 0m 6s
# 	Train Loss: 1.512 | Train PPL:   4.535
# 	 Val. Loss: 1.445 |  Val. PPL:   4.241
# Learning rate:  [5.049114255583167e-05]
# Epoch: 05 | Time: 0m 6s
# 	Train Loss: 1.289 | Train PPL:   3.630
# 	 Val. Loss: 1.336 |  Val. PPL:   3.803
# Learning rate:  [5.6358701359511e-05]
# Epoch: 06 | Time: 0m 6s
# 	Train Loss: 1.204 | Train PPL:   3.334
# 	 Val. Loss: 1.370 |  Val. PPL:   3.935
# Learning rate:  [6.349731077348998e-05]
# Epoch: 07 | Time: 0m 6s
# 	Train Loss: 1.132 | Train PPL:   3.103
# 	 Val. Loss: 1.438 |  Val. PPL:   4.212
# Learning rate:  [7.188740063894322e-05]
# Epoch: 08 | Time: 0m 6s
# 	Train Loss: 1.065 | Train PPL:   2.901
# 	 Val. Loss: 1.482 |  Val. PPL:   4.400
# Learning rate:  [8.150596992279806e-05]
# Epoch: 09 | Time: 0m 6s
# 	Train Loss: 1.017 | Train PPL:   2.765
# 	 Val. Loss: 1.630 |  Val. PPL:   5.105
# Learning rate:  [9.232664977397388e-05]
# Epoch: 10 | Time: 0m 6s
# 	Train Loss: 0.938 | Train PPL:   2.554
# 	 Val. Loss: 1.735 |  Val. PPL:   5.671
# Learning rate:  [0.0001043197758123373]
# Epoch: 11 | Time: 0m 6s
# 	Train Loss: 0.926 | Train PPL:   2.523
# 	 Val. Loss: 1.640 |  Val. PPL:   5.158
# Learning rate:  [0.00011745246945218989]
# Epoch: 12 | Time: 0m 6s
# 	Train Loss: 0.843 | Train PPL:   2.324
# 	 Val. Loss: 1.802 |  Val. PPL:   6.064
# Learning rate:  [0.000131688728037352]
# Epoch: 13 | Time: 0m 6s
# 	Train Loss: 0.872 | Train PPL:   2.391
# 	 Val. Loss: 1.654 |  Val. PPL:   5.227
# Learning rate:  [0.00014698952354073402]
# Epoch: 14 | Time: 0m 6s
# 	Train Loss: 0.761 | Train PPL:   2.141
# 	 Val. Loss: 1.752 |  Val. PPL:   5.766
# Learning rate:  [0.0001633129095578212]
# Epoch: 15 | Time: 0m 6s
# 	Train Loss: 0.804 | Train PPL:   2.235
# 	 Val. Loss: 1.629 |  Val. PPL:   5.101
# Learning rate:  [0.00018061413630074928]
# Epoch: 16 | Time: 0m 6s
# 	Train Loss: 0.782 | Train PPL:   2.185
# 	 Val. Loss: 1.660 |  Val. PPL:   5.260
# Learning rate:  [0.00019884577327772442]
# Epoch: 17 | Time: 0m 6s
# 	Train Loss: 0.765 | Train PPL:   2.149
# 	 Val. Loss: 1.680 |  Val. PPL:   5.364
# Learning rate:  [0.00021795783932146418]
# Epoch: 18 | Time: 0m 6s
# 	Train Loss: 0.756 | Train PPL:   2.130
# 	 Val. Loss: 1.714 |  Val. PPL:   5.549
# Learning rate:  [0.00023789793961019536]
# Epoch: 19 | Time: 0m 6s
# 	Train Loss: 0.714 | Train PPL:   2.042
# 	 Val. Loss: 1.819 |  Val. PPL:   6.165
# Learning rate:  [0.0002586114093055705]
# Epoch: 20 | Time: 0m 6s
# 	Train Loss: 0.677 | Train PPL:   1.968
# 	 Val. Loss: 1.681 |  Val. PPL:   5.373
# Learning rate:  [0.00028004146341372685]
# Epoch: 21 | Time: 0m 6s
# 	Train Loss: 0.671 | Train PPL:   1.957
# 	 Val. Loss: 1.866 |  Val. PPL:   6.461
# Learning rate:  [0.00030212935245865205]
# Epoch: 22 | Time: 0m 6s
# 	Train Loss: 0.661 | Train PPL:   1.936
# 	 Val. Loss: 1.638 |  Val. PPL:   5.144
# Learning rate:  [0.0003248145235410831]
# Epoch: 23 | Time: 0m 6s
# 	Train Loss: 0.639 | Train PPL:   1.895
# 	 Val. Loss: 1.571 |  Val. PPL:   4.813
# Learning rate:  [0.00034803478634140485]
# Epoch: 24 | Time: 0m 6s
# 	Train Loss: 0.665 | Train PPL:   1.945
# 	 Val. Loss: 1.782 |  Val. PPL:   5.940
# Learning rate:  [0.00037172648361145997]
# Epoch: 25 | Time: 0m 6s
# 	Train Loss: 0.645 | Train PPL:   1.905
# 	 Val. Loss: 1.487 |  Val. PPL:   4.425
# Learning rate:  [0.00039582466568787193]
# Epoch: 26 | Time: 0m 6s
# 	Train Loss: 0.673 | Train PPL:   1.960
# 	 Val. Loss: 1.550 |  Val. PPL:   4.711
# Learning rate:  [0.0004202632685484641]
# Epoch: 27 | Time: 0m 6s
# 	Train Loss: 0.610 | Train PPL:   1.840
# 	 Val. Loss: 1.677 |  Val. PPL:   5.349
# Learning rate:  [0.00044497529492364075]
# Epoch: 28 | Time: 0m 6s
# 	Train Loss: 0.622 | Train PPL:   1.862
# 	 Val. Loss: 1.494 |  Val. PPL:   4.456
# Learning rate:  [0.0004698929979662206]
# Epoch: 29 | Time: 0m 6s
# 	Train Loss: 0.587 | Train PPL:   1.798
# 	 Val. Loss: 1.897 |  Val. PPL:   6.669
# Learning rate:  [0.0004949480669762024]
# Epoch: 30 | Time: 0m 6s
# 	Train Loss: 0.646 | Train PPL:   1.908
# 	 Val. Loss: 1.705 |  Val. PPL:   5.499
# Learning rate:  [0.0005200718146713066]
# Epoch: 31 | Time: 0m 6s
# 	Train Loss: 0.608 | Train PPL:   1.838
# 	 Val. Loss: 1.475 |  Val. PPL:   4.370
# Learning rate:  [0.0005451953654898988]
# Epoch: 32 | Time: 0m 6s
# 	Train Loss: 0.610 | Train PPL:   1.840
# 	 Val. Loss: 1.541 |  Val. PPL:   4.669
# Learning rate:  [0.0005702498444100717]
# Epoch: 33 | Time: 0m 6s
# 	Train Loss: 0.577 | Train PPL:   1.780
# 	 Val. Loss: 1.493 |  Val. PPL:   4.450
# Learning rate:  [0.0005951665657672486]
# Epoch: 34 | Time: 0m 6s
# 	Train Loss: 0.586 | Train PPL:   1.797
# 	 Val. Loss: 1.395 |  Val. PPL:   4.033
# Learning rate:  [0.0006198772215526731]
# Epoch: 35 | Time: 0m 6s
# 	Train Loss: 0.566 | Train PPL:   1.761
# 	 Val. Loss: 1.468 |  Val. PPL:   4.342
# Learning rate:  [0.0006443140686765701]
# Epoch: 36 | Time: 0m 6s
# 	Train Loss: 0.588 | Train PPL:   1.801
# 	 Val. Loss: 1.490 |  Val. PPL:   4.435
# Learning rate:  [0.0006684101146826125]
# Epoch: 37 | Time: 0m 6s
# 	Train Loss: 0.603 | Train PPL:   1.828
# 	 Val. Loss: 1.627 |  Val. PPL:   5.087
# Learning rate:  [0.0006920993014045596]
# Epoch: 38 | Time: 0m 6s
# 	Train Loss: 0.566 | Train PPL:   1.762
# 	 Val. Loss: 1.353 |  Val. PPL:   3.868
# Learning rate:  [0.0007153166860615833]
# Epoch: 39 | Time: 0m 6s
# 	Train Loss: 0.603 | Train PPL:   1.828
# 	 Val. Loss: 1.352 |  Val. PPL:   3.866
# Learning rate:  [0.000737998619295819]
# Epoch: 40 | Time: 0m 6s
# 	Train Loss: 0.603 | Train PPL:   1.828
# 	 Val. Loss: 1.458 |  Val. PPL:   4.296
# Learning rate:  [0.0007600829196640593]
# Epoch: 41 | Time: 0m 6s
# 	Train Loss: 0.583 | Train PPL:   1.791
# 	 Val. Loss: 1.402 |  Val. PPL:   4.063
# Learning rate:  [0.0007815090441052278]
# Epoch: 42 | Time: 0m 6s
# 	Train Loss: 0.543 | Train PPL:   1.721
# 	 Val. Loss: 1.362 |  Val. PPL:   3.906
# Learning rate:  [0.0008022182539163073]
# Epoch: 43 | Time: 0m 6s
# 	Train Loss: 0.548 | Train PPL:   1.730
# 	 Val. Loss: 1.443 |  Val. PPL:   4.235
# Learning rate:  [0.0008221537757817061]
# Epoch: 44 | Time: 0m 6s
# 	Train Loss: 0.531 | Train PPL:   1.701
# 	 Val. Loss: 1.485 |  Val. PPL:   4.414
# Learning rate:  [0.0008412609574146066]
# Epoch: 45 | Time: 0m 6s
# 	Train Loss: 0.606 | Train PPL:   1.833
# 	 Val. Loss: 1.654 |  Val. PPL:   5.228
# Learning rate:  [0.0008594874173836161]
# Epoch: 46 | Time: 0m 6s
# 	Train Loss: 0.554 | Train PPL:   1.740
# 	 Val. Loss: 1.489 |  Val. PPL:   4.435
# Learning rate:  [0.0008767831887139738]
# Epoch: 47 | Time: 0m 6s
# 	Train Loss: 0.541 | Train PPL:   1.718
# 	 Val. Loss: 1.549 |  Val. PPL:   4.709
# Learning rate:  [0.0008931008558696405]
# Epoch: 48 | Time: 0m 6s
# 	Train Loss: 0.562 | Train PPL:   1.753
# 	 Val. Loss: 1.203 |  Val. PPL:   3.331
# Learning rate:  [0.0009083956847407389]
# Epoch: 49 | Time: 0m 6s
# 	Train Loss: 0.560 | Train PPL:   1.751
# 	 Val. Loss: 1.428 |  Val. PPL:   4.171
# Learning rate:  [0.0009226257452799935]
# Epoch: 50 | Time: 0m 6s
# 	Train Loss: 0.526 | Train PPL:   1.692
# 	 Val. Loss: 1.450 |  Val. PPL:   4.264
# Learning rate:  [0.0009357520264519634]
# Epoch: 51 | Time: 0m 6s
# 	Train Loss: 0.505 | Train PPL:   1.657
# 	 Val. Loss: 1.571 |  Val. PPL:   4.813
# Learning rate:  [0.000947738543179945]
# Epoch: 52 | Time: 0m 6s
# 	Train Loss: 0.512 | Train PPL:   1.669
# 	 Val. Loss: 1.515 |  Val. PPL:   4.548
# Learning rate:  [0.0009585524349973509]
# Epoch: 53 | Time: 0m 6s
# 	Train Loss: 0.565 | Train PPL:   1.759
# 	 Val. Loss: 1.324 |  Val. PPL:   3.759
# Learning rate:  [0.0009681640561331195]
# Epoch: 54 | Time: 0m 6s
# 	Train Loss: 0.545 | Train PPL:   1.724
# 	 Val. Loss: 1.413 |  Val. PPL:   4.107
# Learning rate:  [0.0009765470567841888]
# Epoch: 55 | Time: 0m 6s
# 	Train Loss: 0.525 | Train PPL:   1.690
# 	 Val. Loss: 1.468 |  Val. PPL:   4.341
# Learning rate:  [0.0009836784553522307]
# Epoch: 56 | Time: 0m 6s
# 	Train Loss: 0.534 | Train PPL:   1.705
# 	 Val. Loss: 1.540 |  Val. PPL:   4.666
# Learning rate:  [0.0009895387014466118]
# Epoch: 57 | Time: 0m 6s
# 	Train Loss: 0.533 | Train PPL:   1.704
# 	 Val. Loss: 1.641 |  Val. PPL:   5.161
# Learning rate:  [0.0009941117294808611]
# Epoch: 58 | Time: 0m 6s
# 	Train Loss: 0.526 | Train PPL:   1.692
# 	 Val. Loss: 1.443 |  Val. PPL:   4.235
# Learning rate:  [0.0009973850027157132]
# Epoch: 59 | Time: 0m 6s
# 	Train Loss: 0.476 | Train PPL:   1.610
# 	 Val. Loss: 1.383 |  Val. PPL:   3.986
# Learning rate:  [0.000999349547627983]
# Epoch: 60 | Time: 0m 6s
# 	Train Loss: 0.514 | Train PPL:   1.672
# 	 Val. Loss: 1.603 |  Val. PPL:   4.966
# Learning rate:  [0.000999999995889394]
# Epoch: 61 | Time: 0m 6s
# 	Train Loss: 0.504 | Train PPL:   1.655
# 	 Val. Loss: 1.497 |  Val. PPL:   4.468
# Learning rate:  [0.0009998726752738695]
# Epoch: 62 | Time: 0m 6s
# 	Train Loss: 0.513 | Train PPL:   1.670
# 	 Val. Loss: 1.313 |  Val. PPL:   3.718
# Learning rate:  [0.000999493654719746]
# Epoch: 63 | Time: 0m 6s
# 	Train Loss: 0.476 | Train PPL:   1.610
# 	 Val. Loss: 1.432 |  Val. PPL:   4.185
# Learning rate:  [0.0009988631250752863]
# Epoch: 64 | Time: 0m 6s
# 	Train Loss: 0.499 | Train PPL:   1.648
# 	 Val. Loss: 1.283 |  Val. PPL:   3.606
# Learning rate:  [0.0009979814038311551]
# Epoch: 65 | Time: 0m 6s
# 	Train Loss: 0.521 | Train PPL:   1.684
# 	 Val. Loss: 1.355 |  Val. PPL:   3.877
# Learning rate:  [0.0009968489349605515]
# Epoch: 66 | Time: 0m 6s
# 	Train Loss: 0.449 | Train PPL:   1.566
# 	 Val. Loss: 1.455 |  Val. PPL:   4.283
# Learning rate:  [0.0009954662886956568]
# Epoch: 67 | Time: 0m 6s
# 	Train Loss: 0.506 | Train PPL:   1.658
# 	 Val. Loss: 1.560 |  Val. PPL:   4.758
# Learning rate:  [0.0009938341612405028]
# Epoch: 68 | Time: 0m 6s
# 	Train Loss: 0.470 | Train PPL:   1.601
# 	 Val. Loss: 1.347 |  Val. PPL:   3.847
# Learning rate:  [0.0009919533744204153]
# Epoch: 69 | Time: 0m 6s
# 	Train Loss: 0.480 | Train PPL:   1.616
# 	 Val. Loss: 1.424 |  Val. PPL:   4.153
# Learning rate:  [0.000989824875268198]
# Epoch: 70 | Time: 0m 6s
# 	Train Loss: 0.475 | Train PPL:   1.609
# 	 Val. Loss: 1.332 |  Val. PPL:   3.787
# Learning rate:  [0.0009874497355472737]
# Epoch: 71 | Time: 0m 6s
# 	Train Loss: 0.467 | Train PPL:   1.595
# 	 Val. Loss: 1.496 |  Val. PPL:   4.465
# Learning rate:  [0.0009848291512120193]
# Epoch: 72 | Time: 0m 6s
# 	Train Loss: 0.476 | Train PPL:   1.610
# 	 Val. Loss: 1.602 |  Val. PPL:   4.963
# Learning rate:  [0.0009819644418055662]
# Epoch: 73 | Time: 0m 6s
# 	Train Loss: 0.492 | Train PPL:   1.636
# 	 Val. Loss: 1.411 |  Val. PPL:   4.101
# Learning rate:  [0.0009788570497953715]
# Epoch: 74 | Time: 0m 6s
# 	Train Loss: 0.491 | Train PPL:   1.635
# 	 Val. Loss: 1.325 |  Val. PPL:   3.761
# Learning rate:  [0.0009755085398468912]
# Epoch: 75 | Time: 0m 6s
# 	Train Loss: 0.475 | Train PPL:   1.608
# 	 Val. Loss: 1.424 |  Val. PPL:   4.155
# Learning rate:  [0.0009719205980357249]
# Epoch: 76 | Time: 0m 6s
# 	Train Loss: 0.461 | Train PPL:   1.586
# 	 Val. Loss: 1.457 |  Val. PPL:   4.292
# Learning rate:  [0.0009680950309986253]
# Epoch: 77 | Time: 0m 6s
# 	Train Loss: 0.473 | Train PPL:   1.605
# 	 Val. Loss: 1.505 |  Val. PPL:   4.506
# Learning rate:  [0.0009640337650238022]
# Epoch: 78 | Time: 0m 6s
# 	Train Loss: 0.475 | Train PPL:   1.608
# 	 Val. Loss: 1.468 |  Val. PPL:   4.339
# Learning rate:  [0.0009597388450809794]
# Epoch: 79 | Time: 0m 6s
# 	Train Loss: 0.486 | Train PPL:   1.626
# 	 Val. Loss: 1.431 |  Val. PPL:   4.181
# Learning rate:  [0.0009552124337916891]
# Epoch: 80 | Time: 0m 6s
# 	Train Loss: 0.450 | Train PPL:   1.568
# 	 Val. Loss: 1.465 |  Val. PPL:   4.326
# Learning rate:  [0.0009504568103403285]
# Epoch: 81 | Time: 0m 6s
# 	Train Loss: 0.476 | Train PPL:   1.610
# 	 Val. Loss: 1.429 |  Val. PPL:   4.175
# Learning rate:  [0.0009454743693265207]
# Epoch: 82 | Time: 0m 6s
# 	Train Loss: 0.462 | Train PPL:   1.587
# 	 Val. Loss: 1.365 |  Val. PPL:   3.914
# Learning rate:  [0.0009402676195593626]
# Epoch: 83 | Time: 0m 6s
# 	Train Loss: 0.444 | Train PPL:   1.559
# 	 Val. Loss: 1.665 |  Val. PPL:   5.286
# Learning rate:  [0.0009348391827941631]
# Epoch: 84 | Time: 0m 6s
# 	Train Loss: 0.444 | Train PPL:   1.559
# 	 Val. Loss: 1.624 |  Val. PPL:   5.075
# Learning rate:  [0.0009291917924123106]
# Epoch: 85 | Time: 0m 6s
# 	Train Loss: 0.416 | Train PPL:   1.516
# 	 Val. Loss: 1.645 |  Val. PPL:   5.180
# Learning rate:  [0.0009233282920449334]
# Epoch: 86 | Time: 0m 6s
# 	Train Loss: 0.418 | Train PPL:   1.519
# 	 Val. Loss: 1.528 |  Val. PPL:   4.608
# Learning rate:  [0.0009172516341410461]
# Epoch: 87 | Time: 0m 6s
# 	Train Loss: 0.423 | Train PPL:   1.527
# 	 Val. Loss: 1.546 |  Val. PPL:   4.692
# Learning rate:  [0.0009109648784809015]
# Epoch: 88 | Time: 0m 6s
# 	Train Loss: 0.439 | Train PPL:   1.551
# 	 Val. Loss: 1.313 |  Val. PPL:   3.718
# Learning rate:  [0.0009044711906353001]
# Epoch: 89 | Time: 0m 6s
# 	Train Loss: 0.433 | Train PPL:   1.541
# 	 Val. Loss: 1.310 |  Val. PPL:   3.704
# Learning rate:  [0.0008977738403716294]
# Epoch: 90 | Time: 0m 6s
# 	Train Loss: 0.434 | Train PPL:   1.543
# 	 Val. Loss: 1.650 |  Val. PPL:   5.205
# Learning rate:  [0.0008908762000074378]
# Epoch: 91 | Time: 0m 6s
# 	Train Loss: 0.431 | Train PPL:   1.539
# 	 Val. Loss: 1.523 |  Val. PPL:   4.586
# Learning rate:  [0.000883781742712371]
# Epoch: 92 | Time: 0m 6s
# 	Train Loss: 0.450 | Train PPL:   1.568
# 	 Val. Loss: 1.439 |  Val. PPL:   4.215
# Learning rate:  [0.0008764940407593268]
# Epoch: 93 | Time: 0m 6s
# 	Train Loss: 0.421 | Train PPL:   1.524
# 	 Val. Loss: 1.423 |  Val. PPL:   4.149
# Learning rate:  [0.0008690167637257075]
# Epoch: 94 | Time: 0m 6s
# 	Train Loss: 0.450 | Train PPL:   1.569
# 	 Val. Loss: 1.390 |  Val. PPL:   4.013
# Learning rate:  [0.0008613536766456773]
# Epoch: 95 | Time: 0m 6s
# 	Train Loss: 0.413 | Train PPL:   1.512
# 	 Val. Loss: 1.383 |  Val. PPL:   3.989
# Learning rate:  [0.000853508638114355]
# Epoch: 96 | Time: 0m 6s
# 	Train Loss: 0.414 | Train PPL:   1.512
# 	 Val. Loss: 1.429 |  Val. PPL:   4.173
# Learning rate:  [0.0008454855983448946]
# Epoch: 97 | Time: 0m 6s
# 	Train Loss: 0.454 | Train PPL:   1.575
# 	 Val. Loss: 1.424 |  Val. PPL:   4.154
# Learning rate:  [0.0008372885971794333]
# Epoch: 98 | Time: 0m 6s
# 	Train Loss: 0.392 | Train PPL:   1.480
# 	 Val. Loss: 1.475 |  Val. PPL:   4.371
# Learning rate:  [0.0008289217620549109]
# Epoch: 99 | Time: 0m 6s
# 	Train Loss: 0.400 | Train PPL:   1.493
# 	 Val. Loss: 1.382 |  Val. PPL:   3.982
# Learning rate:  [0.0008203893059247795]
# Epoch: 100 | Time: 0m 6s
# 	Train Loss: 0.423 | Train PPL:   1.527
# 	 Val. Loss: 1.405 |  Val. PPL:   4.077
# Learning rate:  [0.0008116955251376553]
# Epoch: 101 | Time: 0m 6s
# 	Train Loss: 0.419 | Train PPL:   1.521
# 	 Val. Loss: 1.460 |  Val. PPL:   4.306
# Learning rate:  [0.0008028447972739781]
# Epoch: 102 | Time: 0m 6s
# 	Train Loss: 0.416 | Train PPL:   1.515
# 	 Val. Loss: 1.417 |  Val. PPL:   4.126
# Learning rate:  [0.0007938415789417664]
# Epoch: 103 | Time: 0m 6s
# 	Train Loss: 0.420 | Train PPL:   1.522
# 	 Val. Loss: 1.473 |  Val. PPL:   4.361
# Learning rate:  [0.0007846904035325826]
# Epoch: 104 | Time: 0m 6s
# 	Train Loss: 0.381 | Train PPL:   1.464
# 	 Val. Loss: 1.518 |  Val. PPL:   4.563
# Learning rate:  [0.0007753958789388326]
# Epoch: 105 | Time: 0m 6s
# 	Train Loss: 0.420 | Train PPL:   1.522
# 	 Val. Loss: 1.486 |  Val. PPL:   4.418
# Learning rate:  [0.0007659626852335537]
# Epoch: 106 | Time: 0m 6s
# 	Train Loss: 0.418 | Train PPL:   1.519
# 	 Val. Loss: 1.430 |  Val. PPL:   4.180
# Learning rate:  [0.0007563955723138574]
# Epoch: 107 | Time: 0m 6s
# 	Train Loss: 0.403 | Train PPL:   1.496
# 	 Val. Loss: 1.395 |  Val. PPL:   4.035
# Learning rate:  [0.0007466993575092119]
# Epoch: 108 | Time: 0m 6s
# 	Train Loss: 0.362 | Train PPL:   1.437
# 	 Val. Loss: 1.509 |  Val. PPL:   4.521
# Learning rate:  [0.0007368789231557728]
# Epoch: 109 | Time: 0m 6s
# 	Train Loss: 0.389 | Train PPL:   1.475
# 	 Val. Loss: 1.655 |  Val. PPL:   5.232
# Learning rate:  [0.0007269392141379794]
# Epoch: 110 | Time: 0m 6s
# 	Train Loss: 0.391 | Train PPL:   1.478
# 	 Val. Loss: 1.552 |  Val. PPL:   4.719
# Learning rate:  [0.0007168852353986563]
# Epoch: 111 | Time: 0m 6s
# 	Train Loss: 0.436 | Train PPL:   1.546
# 	 Val. Loss: 1.365 |  Val. PPL:   3.914
# Learning rate:  [0.0007067220494188742]
# Epoch: 112 | Time: 0m 6s
# 	Train Loss: 0.406 | Train PPL:   1.501
# 	 Val. Loss: 1.466 |  Val. PPL:   4.332
# Learning rate:  [0.0006964547736688381]
# Epoch: 113 | Time: 0m 6s
# 	Train Loss: 0.420 | Train PPL:   1.523
# 	 Val. Loss: 1.356 |  Val. PPL:   3.881
# Learning rate:  [0.000686088578031087]
# Epoch: 114 | Time: 0m 6s
# 	Train Loss: 0.409 | Train PPL:   1.506
# 	 Val. Loss: 1.373 |  Val. PPL:   3.946
# Learning rate:  [0.0006756286821973026]
# Epoch: 115 | Time: 0m 6s
# 	Train Loss: 0.389 | Train PPL:   1.475
# 	 Val. Loss: 1.471 |  Val. PPL:   4.354
# Learning rate:  [0.0006650803530400364]
# Epoch: 116 | Time: 0m 6s
# 	Train Loss: 0.369 | Train PPL:   1.446
# 	 Val. Loss: 1.637 |  Val. PPL:   5.138
# Learning rate:  [0.0006544489019606822]
# Epoch: 117 | Time: 0m 6s
# 	Train Loss: 0.424 | Train PPL:   1.528
# 	 Val. Loss: 1.487 |  Val. PPL:   4.423
# Learning rate:  [0.0006437396822150243]
# Epoch: 118 | Time: 0m 6s
# 	Train Loss: 0.369 | Train PPL:   1.447
# 	 Val. Loss: 1.526 |  Val. PPL:   4.601
# Learning rate:  [0.0006329580862177129]
# Epoch: 119 | Time: 0m 6s
# 	Train Loss: 0.366 | Train PPL:   1.442
# 	 Val. Loss: 1.640 |  Val. PPL:   5.155
# Learning rate:  [0.0006221095428270199]
# Epoch: 120 | Time: 0m 6s
# 	Train Loss: 0.394 | Train PPL:   1.483
# 	 Val. Loss: 1.576 |  Val. PPL:   4.837
# Learning rate:  [0.0006111995146112466]
# Epoch: 121 | Time: 0m 6s
# 	Train Loss: 0.378 | Train PPL:   1.460
# 	 Val. Loss: 1.499 |  Val. PPL:   4.477
# Learning rate:  [0.0006002334950981548]
# Epoch: 122 | Time: 0m 6s
# 	Train Loss: 0.380 | Train PPL:   1.463
# 	 Val. Loss: 1.474 |  Val. PPL:   4.368
# Learning rate:  [0.0005892170060088109]
# Epoch: 123 | Time: 0m 6s
# 	Train Loss: 0.361 | Train PPL:   1.435
# 	 Val. Loss: 1.494 |  Val. PPL:   4.457
# Learning rate:  [0.0005781555944772329]
# Epoch: 124 | Time: 0m 6s
# 	Train Loss: 0.423 | Train PPL:   1.526
# 	 Val. Loss: 1.499 |  Val. PPL:   4.476
# Learning rate:  [0.000567054830257241]
# Epoch: 125 | Time: 0m 6s
# 	Train Loss: 0.381 | Train PPL:   1.463
# 	 Val. Loss: 1.512 |  Val. PPL:   4.534
# Learning rate:  [0.0005559203029179196]
# Epoch: 126 | Time: 0m 6s
# 	Train Loss: 0.392 | Train PPL:   1.481
# 	 Val. Loss: 1.405 |  Val. PPL:   4.075
# Learning rate:  [0.0005447576190291001]
# Epoch: 127 | Time: 0m 6s
# 	Train Loss: 0.389 | Train PPL:   1.475
# 	 Val. Loss: 2.005 |  Val. PPL:   7.423
# Learning rate:  [0.0005335723993382844]
# Epoch: 128 | Time: 0m 6s
# 	Train Loss: 0.375 | Train PPL:   1.454
# 	 Val. Loss: 1.467 |  Val. PPL:   4.335
# Learning rate:  [0.0005223702759404298]
# Epoch: 129 | Time: 0m 6s
# 	Train Loss: 0.387 | Train PPL:   1.473
# 	 Val. Loss: 1.466 |  Val. PPL:   4.334
# Learning rate:  [0.000511156889442019]
# Epoch: 130 | Time: 0m 6s
# 	Train Loss: 0.367 | Train PPL:   1.443
# 	 Val. Loss: 1.643 |  Val. PPL:   5.173
# Learning rate:  [0.0004999378861208447]
# Epoch: 131 | Time: 0m 6s
# 	Train Loss: 0.368 | Train PPL:   1.444
# 	 Val. Loss: 1.489 |  Val. PPL:   4.435
# Learning rate:  [0.0004887189150829393]
# Epoch: 132 | Time: 0m 6s
# 	Train Loss: 0.361 | Train PPL:   1.435
# 	 Val. Loss: 1.536 |  Val. PPL:   4.648
# Learning rate:  [0.00047750562541807966]
# Epoch: 133 | Time: 0m 6s
# 	Train Loss: 0.365 | Train PPL:   1.441
# 	 Val. Loss: 1.560 |  Val. PPL:   4.758
# Learning rate:  [0.0004663036633553001]
# Epoch: 134 | Time: 0m 6s
# 	Train Loss: 0.381 | Train PPL:   1.464
# 	 Val. Loss: 1.482 |  Val. PPL:   4.400
# Learning rate:  [0.00045511866941984596]
# Epoch: 135 | Time: 0m 6s
# 	Train Loss: 0.371 | Train PPL:   1.449
# 	 Val. Loss: 1.465 |  Val. PPL:   4.329
# Learning rate:  [0.0004439562755929999]
# Epoch: 136 | Time: 0m 6s
# 	Train Loss: 0.382 | Train PPL:   1.465
# 	 Val. Loss: 1.552 |  Val. PPL:   4.721
# Learning rate:  [0.000432822102476209]
# Epoch: 137 | Time: 0m 6s
# 	Train Loss: 0.339 | Train PPL:   1.404
# 	 Val. Loss: 1.552 |  Val. PPL:   4.723
# Learning rate:  [0.0004217217564609432]
# Epoch: 138 | Time: 0m 6s
# 	Train Loss: 0.338 | Train PPL:   1.402
# 	 Val. Loss: 1.524 |  Val. PPL:   4.592
# Learning rate:  [0.00041066082690570746]
# Epoch: 139 | Time: 0m 6s
# 	Train Loss: 0.374 | Train PPL:   1.454
# 	 Val. Loss: 1.537 |  Val. PPL:   4.648
# Learning rate:  [0.0003996448833216333]
# Epoch: 140 | Time: 0m 6s
# 	Train Loss: 0.358 | Train PPL:   1.431
# 	 Val. Loss: 1.569 |  Val. PPL:   4.801
# Learning rate:  [0.00038867947256805984]
# Epoch: 141 | Time: 0m 6s
# 	Train Loss: 0.398 | Train PPL:   1.489
# 	 Val. Loss: 1.450 |  Val. PPL:   4.263
# Learning rate:  [0.0003777701160595249]
# Epoch: 142 | Time: 0m 6s
# 	Train Loss: 0.366 | Train PPL:   1.442
# 	 Val. Loss: 1.676 |  Val. PPL:   5.346
# Learning rate:  [0.0003669223069855653]
# Epoch: 143 | Time: 0m 6s
# 	Train Loss: 0.348 | Train PPL:   1.417
# 	 Val. Loss: 1.505 |  Val. PPL:   4.505
# Learning rate:  [0.0003561415075447319]
# Epoch: 144 | Time: 0m 6s
# 	Train Loss: 0.370 | Train PPL:   1.448
# 	 Val. Loss: 1.530 |  Val. PPL:   4.618
# Learning rate:  [0.00034543314619420656]
# Epoch: 145 | Time: 0m 6s
# 	Train Loss: 0.397 | Train PPL:   1.488
# 	 Val. Loss: 1.547 |  Val. PPL:   4.700
# Learning rate:  [0.0003348026149164114]
# Epoch: 146 | Time: 0m 6s
# 	Train Loss: 0.365 | Train PPL:   1.441
# 	 Val. Loss: 1.626 |  Val. PPL:   5.082
# Learning rate:  [0.0003242552665039832]
# Epoch: 147 | Time: 0m 6s
# 	Train Loss: 0.360 | Train PPL:   1.434
# 	 Val. Loss: 1.511 |  Val. PPL:   4.531
# Learning rate:  [0.00031379641186448065]
# Epoch: 148 | Time: 0m 6s
# 	Train Loss: 0.374 | Train PPL:   1.453
# 	 Val. Loss: 1.535 |  Val. PPL:   4.642
# Learning rate:  [0.0003034313173461833]
# Epoch: 149 | Time: 0m 6s
# 	Train Loss: 0.360 | Train PPL:   1.433
# 	 Val. Loss: 1.591 |  Val. PPL:   4.909
# Learning rate:  [0.00029316520208632555]
# Epoch: 150 | Time: 0m 6s
# 	Train Loss: 0.362 | Train PPL:   1.436
# 	 Val. Loss: 1.635 |  Val. PPL:   5.131
# Learning rate:  [0.0002830032353831049]
# Epoch: 151 | Time: 0m 6s
# 	Train Loss: 0.329 | Train PPL:   1.389
# 	 Val. Loss: 1.708 |  Val. PPL:   5.518
# Learning rate:  [0.0002729505340927838]
# Epoch: 152 | Time: 0m 6s
# 	Train Loss: 0.381 | Train PPL:   1.464
# 	 Val. Loss: 1.526 |  Val. PPL:   4.598
# Learning rate:  [0.0002630121600531988]
# Epoch: 153 | Time: 0m 6s
# 	Train Loss: 0.329 | Train PPL:   1.390
# 	 Val. Loss: 1.554 |  Val. PPL:   4.731
# Learning rate:  [0.000253193117534973]
# Epoch: 154 | Time: 0m 6s
# 	Train Loss: 0.366 | Train PPL:   1.442
# 	 Val. Loss: 1.692 |  Val. PPL:   5.432
# Learning rate:  [0.00024349835072171456]
# Epoch: 155 | Time: 0m 6s
# 	Train Loss: 0.401 | Train PPL:   1.494
# 	 Val. Loss: 1.688 |  Val. PPL:   5.409
# Learning rate:  [0.00023393274122047178]
# Epoch: 156 | Time: 0m 6s
# 	Train Loss: 0.347 | Train PPL:   1.415
# 	 Val. Loss: 1.573 |  Val. PPL:   4.820
# Learning rate:  [0.00022450110560369676]
# Epoch: 157 | Time: 0m 6s
# 	Train Loss: 0.336 | Train PPL:   1.399
# 	 Val. Loss: 1.554 |  Val. PPL:   4.733
# Learning rate:  [0.00021520819298395604]
# Epoch: 158 | Time: 0m 6s
# 	Train Loss: 0.343 | Train PPL:   1.410
# 	 Val. Loss: 1.595 |  Val. PPL:   4.927
# Learning rate:  [0.00020605868262260965]
# Epoch: 159 | Time: 0m 6s
# 	Train Loss: 0.334 | Train PPL:   1.397
# 	 Val. Loss: 1.594 |  Val. PPL:   4.925
# Learning rate:  [0.00019705718157366194]
# Epoch: 160 | Time: 0m 6s
# 	Train Loss: 0.347 | Train PPL:   1.415
# 	 Val. Loss: 1.615 |  Val. PPL:   5.030
# Learning rate:  [0.00018820822236397113]
# Epoch: 161 | Time: 0m 6s
# 	Train Loss: 0.331 | Train PPL:   1.393
# 	 Val. Loss: 1.606 |  Val. PPL:   4.981
# Learning rate:  [0.00017951626071098552]
# Epoch: 162 | Time: 0m 6s
# 	Train Loss: 0.319 | Train PPL:   1.376
# 	 Val. Loss: 1.619 |  Val. PPL:   5.049
# Learning rate:  [0.00017098567327915578]
# Epoch: 163 | Time: 0m 6s
# 	Train Loss: 0.304 | Train PPL:   1.355
# 	 Val. Loss: 1.592 |  Val. PPL:   4.914
# Learning rate:  [0.00016262075547615232]
# Epoch: 164 | Time: 0m 6s
# 	Train Loss: 0.333 | Train PPL:   1.395
# 	 Val. Loss: 1.578 |  Val. PPL:   4.847
# Learning rate:  [0.0001544257192899984]
# Epoch: 165 | Time: 0m 6s
# 	Train Loss: 0.319 | Train PPL:   1.375
# 	 Val. Loss: 1.628 |  Val. PPL:   5.096
# Learning rate:  [0.00014640469116820713]
# Epoch: 166 | Time: 0m 6s
# 	Train Loss: 0.345 | Train PPL:   1.412
# 	 Val. Loss: 1.561 |  Val. PPL:   4.762
# Learning rate:  [0.00013856170993999093]
# Epoch: 167 | Time: 0m 6s
# 	Train Loss: 0.373 | Train PPL:   1.452
# 	 Val. Loss: 1.543 |  Val. PPL:   4.677
# Learning rate:  [0.00013090072478258953]
# Epoch: 168 | Time: 0m 6s
# 	Train Loss: 0.342 | Train PPL:   1.408
# 	 Val. Loss: 1.559 |  Val. PPL:   4.753
# Learning rate:  [0.00012342559323274012]
# Epoch: 169 | Time: 0m 6s
# 	Train Loss: 0.319 | Train PPL:   1.376
# 	 Val. Loss: 1.590 |  Val. PPL:   4.904
# Learning rate:  [0.00011614007924429161]
# Epoch: 170 | Time: 0m 6s
# 	Train Loss: 0.311 | Train PPL:   1.365
# 	 Val. Loss: 1.640 |  Val. PPL:   5.154
# Learning rate:  [0.00010904785129294026]
# Epoch: 171 | Time: 0m 6s
# 	Train Loss: 0.337 | Train PPL:   1.400
# 	 Val. Loss: 1.601 |  Val. PPL:   4.957
# Learning rate:  [0.000102152480529042]
# Epoch: 172 | Time: 0m 6s
# 	Train Loss: 0.321 | Train PPL:   1.378
# 	 Val. Loss: 1.558 |  Val. PPL:   4.750
# Learning rate:  [9.54574389794304e-05]
# Epoch: 173 | Time: 0m 6s
# 	Train Loss: 0.308 | Train PPL:   1.360
# 	 Val. Loss: 1.630 |  Val. PPL:   5.106
# Learning rate:  [8.896609779914678e-05]
# Epoch: 174 | Time: 0m 6s
# 	Train Loss: 0.324 | Train PPL:   1.383
# 	 Val. Loss: 1.613 |  Val. PPL:   5.016
# Learning rate:  [8.268172557396208e-05]
# Epoch: 175 | Time: 0m 6s
# 	Train Loss: 0.348 | Train PPL:   1.416
# 	 Val. Loss: 1.543 |  Val. PPL:   4.679
# Learning rate:  [7.660748667454545e-05]
# Epoch: 176 | Time: 0m 6s
# 	Train Loss: 0.325 | Train PPL:   1.384
# 	 Val. Loss: 1.598 |  Val. PPL:   4.944
# Learning rate:  [7.074643966310845e-05]
# Epoch: 177 | Time: 0m 6s
# 	Train Loss: 0.315 | Train PPL:   1.370
# 	 Val. Loss: 1.611 |  Val. PPL:   5.006
# Learning rate:  [6.510153575332658e-05]
# Epoch: 178 | Time: 0m 6s
# 	Train Loss: 0.313 | Train PPL:   1.367
# 	 Val. Loss: 1.621 |  Val. PPL:   5.059
# Learning rate:  [5.9675617324314694e-05]
# Epoch: 179 | Time: 0m 6s
# 	Train Loss: 0.333 | Train PPL:   1.395
# 	 Val. Loss: 1.580 |  Val. PPL:   4.853
# Learning rate:  [5.4471416489403235e-05]
# Epoch: 180 | Time: 0m 6s
# 	Train Loss: 0.309 | Train PPL:   1.362
# 	 Val. Loss: 1.609 |  Val. PPL:   4.998
# Learning rate:  [4.949155372043702e-05]
# Epoch: 181 | Time: 0m 6s
# 	Train Loss: 0.345 | Train PPL:   1.412
# 	 Val. Loss: 1.583 |  Val. PPL:   4.868
# Learning rate:  [4.473853652828876e-05]
# Epoch: 182 | Time: 0m 6s
# 	Train Loss: 0.323 | Train PPL:   1.382
# 	 Val. Loss: 1.588 |  Val. PPL:   4.895
# Learning rate:  [4.02147582002517e-05]
# Epoch: 183 | Time: 0m 6s
# 	Train Loss: 0.312 | Train PPL:   1.366
# 	 Val. Loss: 1.604 |  Val. PPL:   4.975
# Learning rate:  [3.592249659494751e-05]
# Epoch: 184 | Time: 0m 6s
# 	Train Loss: 0.350 | Train PPL:   1.418
# 	 Val. Loss: 1.567 |  Val. PPL:   4.794
# Learning rate:  [3.186391299535597e-05]
# Epoch: 185 | Time: 0m 6s
# 	Train Loss: 0.330 | Train PPL:   1.390
# 	 Val. Loss: 1.579 |  Val. PPL:   4.848
# Learning rate:  [2.8041051020543565e-05]
# Epoch: 186 | Time: 0m 6s
# 	Train Loss: 0.344 | Train PPL:   1.410
# 	 Val. Loss: 1.569 |  Val. PPL:   4.803
# Learning rate:  [2.4455835596640118e-05]
# Epoch: 187 | Time: 0m 6s
# 	Train Loss: 0.339 | Train PPL:   1.403
# 	 Val. Loss: 1.585 |  Val. PPL:   4.878
# Learning rate:  [2.1110071987580217e-05]
# Epoch: 188 | Time: 0m 6s
# 	Train Loss: 0.327 | Train PPL:   1.387
# 	 Val. Loss: 1.583 |  Val. PPL:   4.870
# Learning rate:  [1.800544488609871e-05]
# Epoch: 189 | Time: 0m 6s
# 	Train Loss: 0.313 | Train PPL:   1.367
# 	 Val. Loss: 1.584 |  Val. PPL:   4.874
# Learning rate:  [1.5143517565437003e-05]
# Epoch: 190 | Time: 0m 6s
# 	Train Loss: 0.295 | Train PPL:   1.343
# 	 Val. Loss: 1.610 |  Val. PPL:   5.002
# Learning rate:  [1.2525731092187857e-05]
# Epoch: 191 | Time: 0m 6s
# 	Train Loss: 0.309 | Train PPL:   1.362
# 	 Val. Loss: 1.609 |  Val. PPL:   4.999
# Learning rate:  [1.0153403600675246e-05]
# Epoch: 192 | Time: 0m 6s
# 	Train Loss: 0.319 | Train PPL:   1.376
# 	 Val. Loss: 1.606 |  Val. PPL:   4.981
# Learning rate:  [8.027729629233757e-06]
# Epoch: 193 | Time: 0m 6s
# 	Train Loss: 0.329 | Train PPL:   1.389
# 	 Val. Loss: 1.603 |  Val. PPL:   4.967
# Learning rate:  [6.149779518722582e-06]
# Epoch: 194 | Time: 0m 6s
# 	Train Loss: 0.316 | Train PPL:   1.371
# 	 Val. Loss: 1.600 |  Val. PPL:   4.954
# Learning rate:  [4.520498873576907e-06]
# Epoch: 195 | Time: 0m 6s
# 	Train Loss: 0.325 | Train PPL:   1.383
# 	 Val. Loss: 1.602 |  Val. PPL:   4.964
# Learning rate:  [3.1407080856672416e-06]
# Epoch: 196 | Time: 0m 6s
# 	Train Loss: 0.315 | Train PPL:   1.370
# 	 Val. Loss: 1.604 |  Val. PPL:   4.971
# Learning rate:  [2.0111019212077354e-06]
# Epoch: 197 | Time: 0m 6s
# 	Train Loss: 0.307 | Train PPL:   1.360
# 	 Val. Loss: 1.606 |  Val. PPL:   4.982
# Learning rate:  [1.132249170920252e-06]
# Epoch: 198 | Time: 0m 6s
# 	Train Loss: 0.334 | Train PPL:   1.396
# 	 Val. Loss: 1.605 |  Val. PPL:   4.976
# Learning rate:  [5.045923636312246e-07]
# Epoch: 199 | Time: 0m 6s
# 	Train Loss: 0.318 | Train PPL:   1.375
# 	 Val. Loss: 1.605 |  Val. PPL:   4.978
# Learning rate:  [1.284475434449036e-07]
# Epoch: 200 | Time: 0m 6s
# 	Train Loss: 0.323 | Train PPL:   1.381
# 	 Val. Loss: 1.605 |  Val. PPL:   4.975
# Learning rate:  [4.0041106059555345e-09]

# %%
torch.save(model.state_dict(), 'tut4-model2-20.pt')

# %% [markdown]
# Finally, we load the parameters from our best validation loss and get our results on the test set.
#
# We get the improved test perplexity whilst almost being twice as fast!

# %%
model.load_state_dict(torch.load('tut4-model2-20.pt'))

test_loss = evaluate(model, test_iterator, criterion)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# | Test Loss: 1.516 | Test PPL:   4.555 |

# %% [markdown]
# Now, we'll grab some translations from our dataset and see how well our model did. Note, we're going to cherry pick examples here so it gives us something interesting to look at, but feel free to change the `example_idx` value to look at different examples.
#
# First, we'll get a source and target from our dataset.

# %%
example_idx = 12

src = vars(train_data.examples[example_idx])['Sensor']
trg = vars(train_data.examples[example_idx])['Activity']

print(f'src = {src}')
print(f'trg = {trg}')
# Out:
# src = ['63', '63', '63', '1666', '62']
# trg = ['0', '0', '0', '0', '0']

# %% [markdown]
# Then we'll use our `translate_sentence` function to get our predicted translation and attention. We show this graphically by having the source sentence on the x-axis and the predicted translation on the y-axis. The lighter the square at the intersection between two words, the more attention the model gave to that source word when translating that target word.
#
# Below is an example the model attempted to translate, it gets the translation correct except changes *are fighting* to just *fighting*.

# %%
translation, attention = translate_sentence(src, SRC, TRG, model, device)

print(f'predicted trg = {translation}')
# Out:
# predicted trg = ['0', '0', '0', '0', '0', '<eos>']

# %%
display_attention(src, translation, attention)

# %% [markdown]
# Translations from the training set could simply be memorized by the model. So it's only fair we look at translations from the validation and testing set too.
#
# Starting with the validation set, let's get an example.

# %%
example_idx = 14

src = vars(valid_data.examples[example_idx])['Sensor']
trg = vars(valid_data.examples[example_idx])['Activity']

print(f'src = {src}')
print(f'trg = {trg}')
# Out:
# src = ['165', '1', '1', '1', '131']
# trg = ['67', '67', '67', '67', '67']

# %% [markdown]
# Then let's generate our translation and view the attention.
#
# Here, we can see the translation is the same except for swapping *female* with *woman*.

# %%
translation, attention = translate_sentence(src, SRC, TRG, model, device)

print(f'predicted trg = {translation}')

display_attention(src, translation, attention)
# Out:
# predicted trg = ['67', '67', '67', '67', '67', '<eos>']

# %% [markdown]
# Finally, let's get an example from the test set.

# %%
example_idx = 18

src = vars(test_data.examples[example_idx])['Sensor']
trg = vars(test_data.examples[example_idx])['Activity']

print(f'src = {src}')
print(f'trg = {trg}')
# Out:
# src = ['1', '1', '1', '1', '1']
# trg = ['134', '134', '134', '134', '134']

# %% [markdown]
# Again, it produces a slightly different translation than target, a more literal version of the source sentence. It swaps *mountain climbing* for *climbing on a mountain*.

# %%
translation, attention = translate_sentence(src, SRC, TRG, model, device)

print(f'predicted trg = {translation}')

display_attention(src, translation, attention)
# Out:
# predicted trg = ['134', '134', '134', '134', '134', '<eos>']

# %% [markdown]
# We get a BLEU of around 29. If we compare it to the paper that the attention model is attempting to replicate, they achieve a BLEU score of 26.75. This is similar to our score, however they are using a completely different dataset and their model size is much larger - 1000 hidden dimensions which takes 4 days to train! - so we cannot really compare against that either.
#
# This number isn't really interpretable, we can't really say much about it. The most useful part of a BLEU score is that it can be used to compare different models on the same dataset, where the one with the **higher** BLEU score is "better".

# %% [markdown]
# ## BLEU
#
# Previously we have only cared about the loss/perplexity of the model. However there metrics that are specifically designed for measuring the quality of a translation - the most popular is *BLEU*. Without going into too much detail, BLEU looks at the overlap in the predicted and actual target sequences in terms of their n-grams. It will give us a number between 0 and 1 for each sequence, where 1 means there is perfect overlap, i.e. a perfect translation, although is usually shown between 0 and 100. BLEU was designed for multiple candidate translations per source sequence, however in this dataset we only have one candidate per source.
#
# We define a `calculate_bleu` function which calculates the BLEU score over a provided TorchText dataset. This function creates a corpus of the actual and predicted translation for each source sentence and then calculates the BLEU score.

# %%
source_sents = []
target_sents = []
for datum in train_data:
    src = vars(datum)['Sensor']
    trg = vars(datum)['Activity']
    source_sents.append(src)
    target_sents.append(trg)
for datum in valid_data:
    src = vars(datum)['Sensor']
    trg = vars(datum)['Activity']
    source_sents.append(src)
    target_sents.append(trg)
for datum in test_data:
    src = vars(datum)['Sensor']
    trg = vars(datum)['Activity']
    source_sents.append(src)
    target_sents.append(trg)
print(len(source_sents))
print(len(target_sents))
# Out:
# 23769
# 23769

# %%
source_to_target = {}
for i, source in enumerate(source_sents):
  if tuple(source) in source_to_target:
      source_to_target[tuple(source)].append(target_sents[i])
  else:
      source_to_target[tuple(source)] = [target_sents[i]]

# %%
def calculate_bleu(data, src_field, trg_field, model, device, max_len = 50):   
    trgs = []
    pred_trgs = []
    
    for datum in data:
        
        src = vars(datum)['Sensor']
        trg = vars(datum)['Activity']
        pred_trg, _ = translate_sentence(src, src_field, trg_field, model, device, max_len)
        #cut off <eos> token
        pred_trg = pred_trg[:-1]
        # print("A:", pred_trg)
        # print("B:", trg)
        pred_trgs.append(pred_trg)
        trg = source_to_target[tuple(src)]
        trgs.append(trg)
        # print(pred_trgs,trgs)
        # break
    return bleu_score(pred_trgs, trgs)

# %%
bleu_score_a = calculate_bleu(test_data, SRC, TRG, model, device)

print(f'BLEU score = {bleu_score_a*100:.2f}')
# Out:
# BLEU score = 84.29

# %%
source_sents_valid = []
target_sents_valid = []
source_sents_test = []
target_sents_test = []
source_sents_train = []
target_sents_train = []
for datum in valid_data:
    src = vars(datum)['Sensor']
    trg = vars(datum)['Activity']
    source_sents_valid.append(src)
    target_sents_valid.append(trg)
for datum in test_data:
    src = vars(datum)['Sensor']
    trg = vars(datum)['Activity']
    source_sents_test.append(src)
    target_sents_test.append(trg)
for datum in train_data:
    src = vars(datum)['Sensor']
    trg = vars(datum)['Activity']
    source_sents_train.append(src)
    target_sents_train.append(trg)

# %%
def accuracy(source_sents_inp, target_sents_inp, src_field, trg_field, model, device, max_len = 50):   
    total = 0.0
    incorrect_pair = []
    for i, src in enumerate(source_sents_inp):
        pred_trg, _ = translate_sentence(src, src_field, trg_field, model, device, max_len)
        #cut off <eos> token
        pred_trg = pred_trg[:-1]
        trg = target_sents_inp[i]
        if tuple(pred_trg) == tuple(trg):
          total += 1.0
        else:
          incorrect_pair.append([src, trg, pred_trg])
    return total /len(source_sents_inp), incorrect_pair

# %%
acc, incorrect_pair = accuracy(source_sents_test, target_sents_test, SRC, TRG, model, device)

# %%
incorrect_pair[5]
# Out:
# [['405', '206', '63', '285', '1176'],
#  ['134', '134', '134', '105', '105'],
#  ['0', '0', '0', '66', '134']]

# %%
acc
# Out:
# 0.5126050420168067
